# %% [markdown]
# # Computing gcd

# %%
def gcd(m, n):
  common_factors = []
  for i in range(1, min(m, n)+1):
    if m % i == 0 and n % i == 0:
      common_factors.append(i)

  return common_factors[-1]


print(gcd(8, 12))
print(gcd(18, 25))
# Out:
# 4
# 1

# %% [markdown]
# ### Computing gcd - Eliminate the list: `common_factors = []`

# %%
def gcd(m, n):
  for i in range(1, min(m, n)+1):
    if m % i == 0 and n % i == 0:
      largest_common_factor = i

  return largest_common_factor


print(gcd(8, 12))
print(gcd(18, 25))
# Out:
# 4
# 1

# %% [markdown]
# ### Computing gcd - Better Way
#
# $ m = xd, n = yd $
#
# $ m - n = (x - y)d $
#
# $ d $ also divides $ m - n $

# %%
def gcd(m, n):
  a, b = max(m, n), min(m, n)

  print(f'{a=}, {b=}')

  if a % b == 0:
    return b
  else:
    return gcd(b, a-b)


# print(gcd(8, 12))
# print(gcd(18, 25))
# print(gcd(45, 75))
print(gcd(90, 1700))
# Out:
# a=1700, b=90
# a=1610, b=90
# a=1520, b=90
# a=1430, b=90
# a=1340, b=90
# a=1250, b=90
# a=1160, b=90
# a=1070, b=90
# a=980, b=90
# a=890, b=90
# a=800, b=90
# a=710, b=90
# a=620, b=90
# a=530, b=90
# a=440, b=90
# a=350, b=90
# a=260, b=90
# a=170, b=90
# a=90, b=80
# a=80, b=10
# 10

# %% [markdown]
# ### Computing gcd - Euclid’s algorithm

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def gcd(m, n):
  a, b = max(m, n), min(m, n)

  print(f'{a=}, {b=}')

  if a % b == 0:
    return b
  else:
    return gcd(b, a % b)  # 🚀🚀


# print(gcd(8, 12))
# print(gcd(18, 25))
# print(gcd(45, 75))
print(gcd(90, 1700))
# Out:
# a=1700, b=90
# a=90, b=80
# a=80, b=10
# 10
